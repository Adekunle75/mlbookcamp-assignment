# %% [markdown]
# #### Python Crash Course

# %%
# variables 
# containers for values
a = 1
b = 2
c,d,e,f,g,h,i = 3,"Alchemist",5,"Bald",7,True,9

# Scope 
# Refers to the part of a program where a variable is accessible, it can be considered the variable's visibility. 
# For example a variable created in a function is on "global scope", indicating visibility accross the entire program

# %%
# Data Types
#
# Determines the kind of data a variable can have
# There are three main data types i.e. Float, Integer and Strings

# e.g. 2.2,1.052,123.1 --- floats (reps decimals), 2,5,1000 ---- integers (reps whole numbers only), "cake", "2", "3.3" ----- strings
# Built-in functions refer to functions that are already added to a program with a set of statements which together perform a task.
# Typecasting refers to the changing of the data type of a value from one type to another i.e. float to string or integer and vice versa. 
# int() ---- for converting any data type to integer, str()  ---- for converting any data type to string, float()  ---- for converting any data type to floats

# %%
type(f)
# Out:
# str

# %%
print(type(f))
# Out:
# <class 'str'>

# %%
C = str(c)
C
# Out:
# '3'

# %%
type(C)
# Out:
# str
